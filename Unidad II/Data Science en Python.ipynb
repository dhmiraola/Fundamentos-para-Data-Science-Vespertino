# %% [markdown]
# ![CFT-Los-R%C3%ADos.png](attachment:CFT-Los-R%C3%ADos.png)
#
# # Guía de programación básica en Python
#
# ## Curso: Fundamentos para Data Science Vespertino
# ## Profesor: Diego Miranda Olavarría
#
# * Esta guía contiene operaciones básicas para análisis exploratorio de datos en Python

# %% [markdown]
# ### Importar librerías
# #### Antes de empezar a trabajar con bases de datos debes importar las librerías necesarias para trabajar
# #### OJO: Siempre debes importar las librerías antes de empezar a escribir líneas de código

# %%
import pandas as pd # IMPORTANTE: Siempre las librerías debes importarlas al principio
# Out:
# C:\Users\Diego Miranda\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:20: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %% [markdown]
# #### Las bases de datos generalmente vienen en formato Excel (.xlsx), Separados por comas (.csv), SPSS (.sav).

# %% [markdown]
# ### Lectura de datos procedentes desde un CSV

# %%
data = pd.read_csv("titanic3.csv") # pd llama a la librería pandas y le indica que lea un dataframe, en este caso .csv

# %% [markdown]
# #### Con el comando data.head(), puedes ver si la carga de datos ha sido de forma correcta y mostrará por pantalla las 5 primeras filas del dataframe

# %%
data.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.9167      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# ...

# %% [markdown]
# ### Lectura de datos desde ubicación del dataframe

# %%
data2 = pd.read_csv("C:/Users/Diego Miranda/Desktop/Fundamentos de Data Science/Unidad II/titanic3.csv")

# %%
data2.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.9167      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# ...

# %% [markdown]
# #### El comando data.tail() muestra por pantalla las últimas 5 filas del dataframe

# %%
data.tail()
# Out:
#       pclass  survived                       name     sex   age  sibsp  parch  \
# 1304       3         0       Zabour, Miss. Hileni  female  14.5      1      0
# 1305       3         0      Zabour, Miss. Thamine  female   NaN      1      0
# 1306       3         0  Zakarian, Mr. Mapriededer    male  26.5      0      0
# 1307       3         0        Zakarian, Mr. Ortin    male  27.0      0      0
# 1308       3         0         Zimmerman, Mr. Leo    male  29.0      0      0
#
#       ticket     fare cabin embarked boat   body home.dest
# 1304    2665  14.4542   NaN        C  NaN  328.0       NaN
# 1305    2665  14.4542   NaN        C  NaN    NaN       NaN
# 1306    2656   7.2250   NaN        C  NaN  304.0       NaN
# 1307    2670   7.2250   NaN        C  NaN    NaN       NaN
# 1308  315082   7.8750   NaN        S  NaN    NaN       NaN

# %% [markdown]
# ### Lectura de datos desde una hoja de cálculo (Excel)

# %%
data_excel = pd.read_excel("titanic3.xlsx")

# %%
data_excel.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.9167      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# ...

# %%
data_excel2 = pd.read_excel("C:/Users/Diego Miranda/Desktop/Fundamentos de Data Science/Unidad II/titanic3.xlsx")

# %%
data_excel2.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.9167      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# ...

# %% [markdown]
# ### El comando .shape muestra la dimensión del dataframe (número de filas y columnas)

# %%
data.shape # El dataset contiene 1309 filas y 14 columnas
# Out:
# (1309, 14)

# %% [markdown]
# ### El comando .columns.values muestra los valores de las cabeceras del dataframe

# %%
data.columns.values
# Out:
# array(['pclass', 'survived', 'name', 'sex', 'age', 'sibsp', 'parch',
#        'ticket', 'fare', 'cabin', 'embarked', 'boat', 'body', 'home.dest'],
#       dtype=object)

# %% [markdown]
# ### El comando len() muestra la longitud de dataframe

# %%
len(data)
# Out:
# 1309

# %% [markdown]
# ### Estadísticos básicos de las variables numéricas

# %%
data.describe()

# este comando muestra por pantalla los estadísticos básicos:
# count = número total de objetos por columna
# mean = promedio
# std = desviación estandar, variación o dispersión en la que los puntos de datos individuales difieren de la media
# min = valor mínimo
# max = valor máximo
# Out:
#             pclass     survived          age        sibsp        parch  \
# count  1309.000000  1309.000000  1046.000000  1309.000000  1309.000000
# mean      2.294882     0.381971    29.881135     0.498854     0.385027
# std       0.837836     0.486055    14.413500     1.041658     0.865560
# min       1.000000     0.000000     0.166700     0.000000     0.000000
# 25%       2.000000     0.000000    21.000000     0.000000     0.000000
# 50%       3.000000     0.000000    28.000000     0.000000     0.000000
# 75%       3.000000     1.000000    39.000000     1.000000     0.000000
# max       3.000000     1.000000    80.000000     8.000000     9.000000
#
#               fare        body
# count  1308.000000  121.000000
# mean     33.295479  160.809917
# std      51.758668   97.696922
# min       0.000000    1.000000
# 25%       7.895800   72.000000
# 50%      14.454200  155.000000
# 75%      31.275000  256.000000
# max     512.329200  328.000000

# %% [markdown]
# ### dtypes muestra el tipo de dato de cada una de las variables

# %%
data.dtypes
# Out:
# pclass         int64
# survived       int64
# name          object
# sex           object
# age          float64
# sibsp          int64
# parch          int64
# ticket        object
# fare         float64
# cabin         object
# embarked      object
# boat          object
# body         float64
# home.dest     object
# dtype: object

# %% [markdown]
# ### De esta forma seleccionas una columna del dataframe

# %%
data["survived"]
# Out:
# 0       1
# 1       1
# 2       0
# 3       0
# 4       0
#        ..
# 1304    0
# 1305    0
# 1306    0
# 1307    0
# 1308    0
# Name: survived, Length: 1309, dtype: int64

# %% [markdown]
# ### Crear un subconjunto de datos

# %%
subset = data["survived"] # Cuando se elije una sola columna se utiliza solo 1 corchete
subset.head()
# Out:
# 0    1
# 1    1
# 2    0
# 3    0
# 4    0
# Name: survived, dtype: int64

# %%
subset2 = data[["survived", "age", "home.dest"]] # Cuando se elijen 2 o más columnas se utilizan 2 corchetes
subset2.head()
# Out:
#    survived      age                        home.dest
# 0         1  29.0000                     St Louis, MO
# 1         1   0.9167  Montreal, PQ / Chesterville, ON
# 2         0   2.0000  Montreal, PQ / Chesterville, ON
# 3         0  30.0000  Montreal, PQ / Chesterville, ON
# 4         0  25.0000  Montreal, PQ / Chesterville, ON

# %% [markdown]
# ### Subconjunto de datos con condiciones

# %%
cond = data["age"]<18
cond.head()
# Out:
# 0    False
# 1     True
# 2     True
# 3    False
# 4    False
# Name: age, dtype: bool

# %%
# AND se usa para 

sub_cond = data[(data["survived"]==0) & (data["age"]>18)]
sub_cond.head()
# Out:
#     pclass  survived                                             name     sex  \
# 3        1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4        1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# 7        1         0                           Andrews, Mr. Thomas Jr    male
# 9        1         0                          Artagaveytia, Mr. Ramon    male
# 10       1         0                           Astor, Col. John Jacob    male
#
#      age  sibsp  parch    ticket      fare    cabin embarked boat   body  \
# 3   30.0      1      2    113781  151.5500  C22 C26        S  NaN  135.0
# 4   25.0      1      2    113781  151.5500  C22 C26        S  NaN    NaN
# 7   39.0      0      0    112050    0.0000      A36        S  NaN    NaN
# 9   71.0      0      0  PC 17609   49.5042      NaN        C  NaN   22.0
# 10  47.0      1      0  PC 17757  227.5250  C62 C64        C  NaN  124.0
#
#                           home.dest
# ...

# %%
sub_cond.shape
# Out:
# (521, 14)

# %% [markdown]
# ### Creación de un subset con un número determinado de filas

# %%
data_num = data.sample(100)
data_num.shape
# Out:
# (100, 14)

# %%
len(data_num)
# Out:
# 100

# %% [markdown]
# ### El comando groupby selecciona una columna determinada y divide en grupos los valores

# %%
data.groupby("sex").size()
# Out:
# sex
# female    466
# male      843
# dtype: int64

# %%
data.groupby("pclass").size()
# Out:
# pclass
# 1    323
# 2    277
# 3    709
# dtype: int64

# %% [markdown]
# ### Ejercicios: Abra un dataframe y pruebe los códigos vistos en clases.

# %% [markdown]
# ### Renombrar columnas

# %%
renombrar = data.rename(columns={"pclass":"clase"})
renombrar.head()
# Out:
#    clase  survived                                             name     sex  \
# 0      1         1                    Allen, Miss. Elisabeth Walton  female
# 1      1         1                   Allison, Master. Hudson Trevor    male
# 2      1         0                     Allison, Miss. Helen Loraine  female
# 3      1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4      1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.9167      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# ...

# %%
renombrar = data.rename(columns={"name":"nombre","age":"edad","sex":"género"})
renombrar.head()
# Out:
#    pclass  survived                                           nombre  género  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#       edad  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.9167      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# ...
